# %%
# %load_ext autoreload
# %autoreload 2

import _metrics


import cv2
import glob
import numpy as np
import mahotas as mh
import os
import uuid
import tifffile as tif
from scipy import ndimage as nd
from scipy.misc import imrotate
import skimage.measure
import random
import cPickle as pickle

from matplotlib.pyplot import imshow
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_PATH = '/Volumes/DATA1/EMQM_DATA/ac3x75/'
GOLD_PATH = os.path.join(DATA_PATH,'gold/')
IMAGE_PATH = os.path.join(DATA_PATH,'input/')
TRAINING_PATH = os.path.join(DATA_PATH,'training/')

# %%
gold = _metrics.Util.read(GOLD_PATH+'*.tif')
images = _metrics.Util.read(IMAGE_PATH+'*.tif')
# Out:
# Loaded 75 images.
# Loaded
#  75 images.

# %%
imshow(gold[0])

# %%
import time

t0 = time.time()
splits = 0
data = []
for s in _metrics.SplitError.generate(images[0:1,600:800,200:400], gold[0:1,600:800,200:400], 1, thumb=False, rotate=True):
    splits += 1
    #data.append(s)

t1 = time.time()

total = t1-t0

print total, 'seconds for', splits, 'splits'
# Out:
# 0.447484970093 seconds for 84 splits

# %%
imshow(data[0]._meta['label1'])

# %%
imshow(data[1]._meta['label1'])

# %%
imshow(data[2]._thumb)

# %%
imshow(data[3]._thumb)
