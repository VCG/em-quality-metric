# %%
# %load_ext autoreload
# %autoreload 2

import _metrics


import cv2
import glob
import numpy as np
import mahotas as mh
import os
import uuid
import tifffile as tif
from scipy import ndimage as nd
from scipy.misc import imrotate
import skimage.measure
import random
import cPickle as pickle

from matplotlib.pyplot import imshow
# %matplotlib inline
# Out:
# _metrics/tifffile.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# _metrics/tifffile.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# _metrics/tifffile.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)

# %%
DATA_PATH = '/Volumes/DATA1/EMQM_DATA/ac3x75/'
GOLD_PATH = os.path.join(DATA_PATH,'gold/')
IMAGE_PATH = os.path.join(DATA_PATH,'input/')
PROB_PATH = os.path.join(DATA_PATH,'prob/')
TRAINING_PATH = os.path.join(DATA_PATH,'training/')

# %%
gold = _metrics.Util.read(GOLD_PATH+'*.tif')
images = _metrics.Util.read(IMAGE_PATH+'*.tif')
probs = _metrics.Util.read(PROB_PATH+'*.tif')
# Out:
# Loaded 75 images.
# Loaded
#  75 images.
# Loaded
#  75 images.

# %%
imshow(gold[0])

# %%
import time

t0 = time.time()
splits = 0
data = []
for s in _metrics.SplitError.generate(images[0:1], probs[0:1], gold[0:1], 1, thumb=False, rotate=True):
#for s in _metrics.SplitError.generate(images, gold, 10, thumb=False, rotate=True):    
    splits += 1
    if splits % 1000 == 0:
        print 'Another 1000 generated.'
    #data.append(s)

    t1 = time.time()
    total = t1-t0
    
    if total > 100:
        break




print total, 'seconds for', splits, 'splits'
# Out:
# Working on z 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-439458aaadab> in <module>()
#       4 splits = 0
#       5 data = []
# ----> 6 for s in _metrics.SplitError.generate(images[0:1], probs[0:1], gold[0:1], 1, thumb=False, rotate=True):
#       7 #for s in _metrics.SplitError.generate(images, gold, 10, thumb=False, rotate=True):
#       8     splits += 1
#
# /Users/d/Projects/em-quality-metric/Code/_metrics/split_error.py in generate(image, prob, label, n, thumb, rotate)
#      93                     upper_limit = 3
#      94
# ---> 95                     s = SplitError.create(image[z], prob[z], label_filled_relabeled, l, thumb)
#      96                     while not s:
#      97
#
# /Users/d/Projects/em-quality-metric/Code/_metrics/split_error.py in create(image, prob, segmentation, label, thumb)
#      51         m = SplitError()
# ...

# %%
s._meta.keys()
# Out:
# ['label1', 'image', 'overlap', 'prob', 'merge', 'label2']

# %%
imshow(s._meta['prob'])

# %%
imshow(s._meta['image'])

# %%
imshow(s._meta['label1'])

# %%
imshow(s._meta['label2'])

# %%
imshow(s._meta['overlap'])

# %%
imshow(s._thumb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e9ff9e2de4c6> in <module>()
# ----> 1 imshow(s._thumb)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, **kwargs)
#    2375         ax.hold(hold)
#    2376     try:
# -> 2377         ret = ax.imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    2378         draw_if_interactive()
#    2379     finally:
#
# ...

# %%
imshow(data[3]._thumb)
