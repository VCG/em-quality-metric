# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

from split_cnn import SplitCNN

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is disabled)

# %%
s = SplitCNN()

# %%
layers = s.run()
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 5 took 8.007s
#   training loss:		6.978536
#   validation loss:		0.576077
#   validation accuracy:		78.00 %
# Epoch 2 of 5 took 7.992s
#   training loss:		0.789246
#   validation loss:		0.344170
#   validation accuracy:		87.50 %
# Epoch 3 of 5 took 8.002s
#   training loss:		0.561318
#   validation loss:		0.315539
#   validation accuracy:		85.50 %
# Epoch 4 of 5 took 8.004s
#   training loss:		0.495939
#   validation loss:		0.172445
#   validation accuracy:		96.00 %
# Epoch 5 of 5 took 8.012s
#   training loss:		0.438737
#   validation loss:		0.154572
#   validation accuracy:		96.50 %
# Final results:
#   test loss:			0.154572
#   test accuracy:		96.50 %

# %%
# normalize binary images to 0-255
layers = s.run()
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 5 took 8.049s
#   training loss:		58.121798
#   validation loss:		0.555181
#   validation accuracy:		80.50 %
# Epoch 2 of 5 took 7.995s
#   training loss:		0.841037
#   validation loss:		0.150186
#   validation accuracy:		94.50 %
# Epoch 3 of 5 took 8.050s
#   training loss:		0.329825
#   validation loss:		0.072592
#   validation accuracy:		99.00 %
# Epoch 4 of 5 took 7.973s
#   training loss:		0.221343
#   validation loss:		0.053416
#   validation accuracy:		99.50 %
# Epoch 5 of 5 took 8.023s
#   training loss:		0.179309
#   validation loss:		0.026101
#   validation accuracy:		100.00 %
# Final results:
#   test loss:			0.026101
#   test accuracy:		100.00 %

# %%
# first test with real val and test data
layers = s.run()
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 5 took 4.855s
#   training loss:		46.845620
#   validation loss:		0.440811
#   validation accuracy:		80.00 %
# Epoch 2 of 5 took 4.789s
#   training loss:		1.028028
#   validation loss:		0.317996
#   validation accuracy:		85.00 %
# Epoch 3 of 5 took 4.821s
#   training loss:		0.541701
#   validation loss:		0.323557
#   validation accuracy:		85.00 %
# Epoch 4 of 5 took 4.790s
#   training loss:		0.294658
#   validation loss:		0.318042
#   validation accuracy:		90.00 %
# Epoch 5 of 5 took 4.819s
#   training loss:		0.240135
#   validation loss:		0.301954
#   validation accuracy:		85.00 %
# Final results:
#   test loss:			0.611263
#   test accuracy:		65.00 %

# %%
layers = s.run()
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 5 took 4.852s
#   training loss:		79.301406
#   validation loss:		1.692208
#   validation accuracy:		70.00 %
# Epoch 2 of 5 took 4.829s
#   training loss:		1.434582
#   validation loss:		0.455345
#   validation accuracy:		75.00 %
# Epoch 3 of 5 took 4.870s

# %%
imshow(s._dbg[0][4].reshape(75,75))

# %%
# this time with input shape[0] == 500 for a fixed batch size
# note: does not make much of a difference
layers = s.run()
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 5 took 50.232s
#   training loss:		1.298496
#   validation loss:		0.296672
#   validation accuracy:		91.71 %
# Epoch 2 of 5 took 50.148s
#   training loss:		0.378147
#   validation loss:		0.166874
#   validation accuracy:		95.15 %
# Epoch 3 of 5 took 50.149s
#   training loss:		0.256131
#   validation loss:		0.125012
#   validation accuracy:		96.40 %
# Epoch 4 of 5 took 50.145s
#   training loss:		0.205479
#   validation loss:		0.101929
#   validation accuracy:		97.02 %
# Epoch 5 of 5 took 50.152s
#   training loss:		0.172785
#   validation loss:		0.090450
#   validation accuracy:		97.37 %
# Final results:
#   test loss:			0.086888
#   test accuracy:		97.29 %
# /Users/d/Library/Python/2.7/lib/python/site-packages/theano/tensor/nnet/__init__.py:111: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   warnings.warn("The `image_shape` keyword argument to "

# %%
layers
# Out:
# {'binary1': {'c2d_layer': <lasagne.layers.conv.Conv2DLayer at 0x11b716850>,
#   'c2d_layer2': <lasagne.layers.conv.Conv2DLayer at 0x11b716910>,
#   'input_layer': <lasagne.layers.input.InputLayer at 0x11b716890>,
#   'max_pool_layer': <lasagne.layers.pool.MaxPool2DLayer at 0x11b7168d0>,
#   'max_pool_layer2': <lasagne.layers.pool.MaxPool2DLayer at 0x11b716bd0>,
#   'network': <lasagne.layers.pool.MaxPool2DLayer at 0x11b716bd0>},
#  'dense': {'dense_layer1': <lasagne.layers.dense.DenseLayer at 0x11b716ed0>,
#   'dense_layer2': <lasagne.layers.dense.DenseLayer at 0x11b71c610>,
#   'network': <lasagne.layers.dense.DenseLayer at 0x11b71c610>},
#  'image': {'c2d_layer': <lasagne.layers.conv.Conv2DLayer at 0x112774f10>,
#   'c2d_layer2': <lasagne.layers.conv.Conv2DLayer at 0x11279cc10>,
#   'input_layer': <lasagne.layers.input.InputLayer at 0x11b6ff410>,
#   'max_pool_layer': <lasagne.layers.pool.MaxPool2DLayer at 0x10f76ac10>,
# ...

# %%
imshow(s.visualize_filters(layers['binary1']['c2d_layer']), cmap='gray')

# %%
imshow(s.visualize_filters(layers['image']['c2d_layer']), cmap='gray')

# %%
fig2 = plt.figure(figsize = (5,5)) # create a 5 x 5 figure 
ax3 = fig2.add_subplot(111)
ax3.imshow(s.visualize_filters(layers['image']['c2d_layer']), cmap='gray')
ax3.set_title('larger figure')

plt.show()
