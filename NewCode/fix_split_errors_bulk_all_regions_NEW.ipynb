# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline


import cv2
import glob
import numpy as np
import mahotas as mh
import os
import uuid
import tifffile as tif
from scipy import ndimage as nd
from scipy.misc import imrotate
import skimage.measure
from skimage import img_as_ubyte
import random
import cPickle as pickle
import time
import partition_comparison
import copy
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

import _metrics

DATA_PATH = '/Volumes/DATA1/EMQM_DATA/ac3x75/'
GOLD_PATH = os.path.join(DATA_PATH,'gold/')
RHOANA_PATH = os.path.join(DATA_PATH,'rhoana/')
IMAGE_PATH = os.path.join(DATA_PATH,'input/')
PROB_PATH = os.path.join(DATA_PATH,'prob/')
PATCH_PATH = os.path.join(DATA_PATH,'test_rhoana/')
OUTPUT_PATH = '/Volumes/DATA1/bulk_split_errors/'
# Out:
# tifffile.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)

# %%
from fix_split_errors_new import *



val_fn = setup_n()
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is disabled)
# /Users/d/Library/Python/2.7/lib/python/site-packages/theano/tensor/nnet/__init__.py:111: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   warnings.warn("The `image_shape` keyword argument to "
# Loading ['/Volumes/DATA1/split_cnn/patches_3rd_small/a6d1924e-059c-4987-8512-da16a8d1aaee/configuration.txt']
# ["{'outputpath': '/Volumes/DATA1/split_cnn/patches_3rd_small/', 'uuid': 'a6d1924e-059c-4987-8512-da16a8d1aaee', 'filtersize1': 5, 'filters3': 32, 'filters2': 32, 'batchsize': 100, 'datapath': '/Volumes/DATA1/EMQM_DATA/ac3x75/', 'epochs': 20, 'runmode': 'local', 'filtersize2': 5, 'filtersize3': 5, 'filters1': 32, 'patchpath': 'patches_3rd_small', 'thirdconvlayer': False, 'learning_rate': 0.0001, 'momentum': 0.9}"]
# Loading ['/Volumes/DATA1/split_cnn/patches_3rd_small/a6d1924e-059c-4987-8512-da16a8d1aaee/network_19.p']

# %%
slices = [70,71]#,72,73,74]
splits_per_label = [1,2]#,3,4,5]

best_surenesses = []
bboxes = []
global_vis = []
global_before_vis = []
global_diff_vis = []
global_slices = []
global_splits = []

for b in range(100,900,200):
    for b2 in range(100,900,200):
        
        BBOX = [b, b+200, b2, b2+200]

        for splits in splits_per_label:

            for s in slices:
                gold = mh.imread(GOLD_PATH+'ac3_labels_00'+str(s)+'.tif')
                rhoana = mh.imread(RHOANA_PATH+os.sep+"z=000000"+str(s)+".tif")
                input_image = mh.imread(IMAGE_PATH+'ac3_input_00'+str(s)+'.tif')
                prob = mh.imread(PROB_PATH+'ac3_input_00'+str(s)+'_syn.tif')


                image = input_image[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]]
                prob = prob[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]]
                seg = _metrics.Util.normalize_labels(rhoana[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]])[0]



                # fill and normalize gold
                gold_zeros = _metrics.Util.threshold(gold[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]], 0)
                gold_filled = _metrics.Util.fill(gold[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]], gold_zeros.astype(np.bool))
                gold_filled_relabeled = skimage.measure.label(gold_filled).astype(np.uint64)
                gold_normalized = _metrics.Util.normalize_labels(gold_filled_relabeled)[0]

                # color both segmentations
                cm = _metrics.Util.load_colormap('/Volumes/DATA1/ac3x75/mojo/ids/colorMap.hdf5')
                colored_rhoana_normalized = cm[seg % len(cm)]
                colored_gold_normalized = cm[gold_normalized % len(cm)]

                gold_framed = np.array(gold_normalized)
                gold_framed[:38] = 0
                gold_framed[-38:] = 0
                gold_framed[:,0:38] = 0
                gold_framed[:,-38:] = 0
                #imshow(gold_framed)    

                image_framed = np.array(image)
                #imshow(image_framed,cmap='gray')    

                split_gold_normalized = create_spliterrors(image_framed, gold_normalized, splits).astype(np.uint64)
                split_gold_normalized = _metrics.Util.normalize_labels(split_gold_normalized)[0]
                colored_split_gold_normalized = cm[split_gold_normalized % len(cm)]
                split_gold_normalized_framed = np.array(split_gold_normalized)
                #imshow(split_gold_normalized.astype(np.uint64))    

                t0 = time.time()
                p = loop(image, prob, split_gold_normalized_framed)
                print len(p), 'patches generated in',time.time()-t0,'seconds'


                m_new = create_matrix(val_fn, split_gold_normalized_framed, p)

                t0 = time.time()
                out = split_gold_normalized_framed
                sureness = 0.


                surenesses = []
                vi_s = []
                _images = [out]

                before_VI = partition_comparison.variation_of_information(split_gold_normalized_framed.ravel(), gold_framed.ravel())

                while m_new.max() >= sureness:

                    old_image = np.array(out)
                    m_old = np.array(m_new)

                    surenesses.append(m_new.max())    

                    m_new, out, patches, l, n = merge(val_fn, image, out, prob, m_new)

                    vi = partition_comparison.variation_of_information(out.ravel(), gold_framed.ravel())
                    vi_s.append(vi)    



                # create plot
                index = vi_s.index(min(vi_s))
                out_text = 'Before VI ' + str(before_VI) + '\n'
                out_text += 'Lowest VI ' + str(vi_s[index]) + '\n'
                out_text += 'Iterations ' + str(index) + '\n'
                out_text += 'Sureness ' + str(surenesses[index]) + '\n'
                out_text += 'Ran in ' + str(time.time()-t0) + ' seconds\n'

                best_surenesses.append(surenesses[index])
                bboxes.append(BBOX)
                global_vis.append(vi_s[index])
                global_before_vis.append(before_VI)
                global_slices.append(s)
                global_diff_vis.append(before_VI - vi_s[index])
                global_splits.append(splits)

                new_rhoana = propagate_max_overlap(split_gold_normalized, gold_framed)
                target_vi = partition_comparison.variation_of_information(new_rhoana.ravel(), gold_framed.ravel())

                bins = np.arange(0, len(vi_s))#np.arange(len(vi_s), 0, -1)
                # bins /= 100

                vi_s_ = vi_s #[x for (y,x) in sorted(zip(surenesses, vi_s))]
                surenesses_ = bins #surenesses#[y for (y,x) in sorted(zip(surenesses, vi_s))]

                original_vi = [before_VI]*len(vi_s)
                target_vi = [target_vi]*len(vi_s)

                fig, ax = plt.subplots()
                fig.text(0,1,'\n\n\n\n\n'+out_text)

                ax.plot(surenesses_, target_vi, 'k--', label='Target VI')
                ax.plot(surenesses_, vi_s_, 'k', label='Variation of Information')
                ax.plot(surenesses_, original_vi, 'k:', label='VI before')
                # ax.set_yscale('log')

                # Now add the legend with some customizations.
                legend = ax.legend(loc='upper center', shadow=True)
                ax.set_ylim([-0.5,1.5])

                # The frame is matplotlib.patches.Rectangle instance surrounding the legend.
                frame = legend.get_frame()
                frame.set_facecolor('0.90')

                # Set the fontsize
                for label in legend.get_texts():
                    label.set_fontsize('large')

                for label in legend.get_lines():
                    label.set_linewidth(1.5)  # the legend line width

                plt.savefig(OUTPUT_PATH+os.sep+'result'+str(s)+'.png')
# Out:
# 246 patches generated in 3.24638009071 seconds
# 358
#  patches generated in 4.67838001251 seconds
# 506
#  patches generated in 5.84217000008 seconds
# 480
#  patches generated in 5.91273498535 seconds
# 846
#  patches generated in 9.04932808876 seconds
# 686
#  patches generated in 7.5166862011 seconds
# 1288
#  patches generated in 13.3194670677 seconds
# 1246
#  patches generated in 12.9957249165 seconds
# 308
#  patches generated in 4.10284495354 seconds
# 280
#  patches generated in 3.82783102989 seconds
# 608
#  patches generated in 6.98510193825 seconds
# 516
#  patches generated in 6.1283891201 seconds
# 145
#  patches generated in 1.77578306198 seconds
# 130
#  patches generated in 1.64274907112 seconds
# 249
#  patches generated in 2.84486913681 seconds
# 274
#  patches generated in 3.08195495605 seconds
# 168
#  patches generated in 2.14709496498 seconds
# 113
#  patches generated in 1.59097218513 seconds
# 252
#  patches generated in 2.99430179596 seconds
# 336
#  patches generated in 3.9153418541 seconds
# 360
#  patches generated in 4.66654491425 seconds
# 282
#  patches generated in 3.58094596863 seconds
# 511
#  patches generated in 6.46884799004 seconds
# 425
#  patches generated in 5.19679713249 seconds
# 960
#  patches generated in 10.4005579948 seconds
# 1082
#  patches generated in 11.3395080566 seconds
# 1576
#  patches generated in 16.5144588947 seconds
# 1621
#  patches generated in 16.5194480419 seconds
# 674
#  patches generated in 7.43356800079 seconds
# 998
#  patches generated in 10.4931471348 seconds
# 998
#  patches generated in 10.7199399471 seconds
# 1684
#  patches generated in 17.1691970825 seconds
# 132
#  patches generated in 1.85536003113 seconds
# 174
#  patches generated in 2.24516797066 seconds
# 181
#  patches generated in 2.45927906036 seconds
# 290
#  patches generated in 3.58250403404 seconds
# 388
#  patches generated in 4.49853491783 seconds
# 452
#  patches generated in 5.30448102951 seconds
# 460
#  patches generated in 5.6076130867 seconds
# 646
#  patches generated in 7.27877807617 seconds
# 635
#  patches generated in 7.42041492462 seconds
# 390
#  patches generated in 4.71846413612 seconds
# 918
#  patches generated in 10.0886659622 seconds
# 672
#  patches generated in 7.93164896965 seconds
# 536
#  patches generated in 5.88402509689 seconds
# 906
#  patches generated in 9.78363704681 seconds
# 1016
#  patches generated in 10.9188919067 seconds
# 1096
#  patches generated in 11.7067489624 seconds
# 516
#  patches generated in 6.08578705788 seconds
# 708
#  patches generated in 7.42308616638 seconds
# 850
#  patches generated in 8.95770406723 seconds
# 1082
#  patches generated in 11.7217450142 seconds
# 870
#  patches generated in 9.50702095032 seconds
# 774
#  patches generated in 8.45201897621 seconds
# 1414
#  patches generated in 14.6394999027 seconds
# 1026
#  patches generated in 10.9244370461 seconds
# 242
#  patches generated in 3.63640117645 seconds
# 145
#  patches generated in 2.20133495331 seconds
# 292
#  patches generated in 3.85923099518 seconds
# 268
#  patches generated in 3.30671811104 seconds
# 384
#  patches generated in 4.79519796371 seconds
# 418
#  patches generated in 5.0385260582 seconds
# 528
#  patches generated in 6.13307094574 seconds
# 600
#  patches generated in 7.01094698906 seconds

# %%
best_surenesses
# Out:
# [0.99913120865821836,
#  1.0,
#  0.96952046481909937,
#  0.99866280705917465,
#  0.94037420302629471,
#  0.96393641666932539,
#  1.0,
#  0.8407416073307018,
#  1.0,
#  0.95806135845345419,
#  0.98098409814493992,
#  0.99999992847442631,
#  0.91136870990220575,
#  0.98244945243253545,
#  0.590926646654095,
#  0.77324707309405005,
#  0.99255746566778258,
#  0.75540479377734882,
#  0.99624896453829803,
#  1.0,
#  0.99495542640770351,
#  0.99993944993025718,
#  0.77749047615444389,
#  0.99979482401220288,
#  1.0,
#  0.86937445402145386,
#  0.93128188030491954,
#  1.0,
#  0.78474036285483384,
#  0.97014658153057098,
#  0.99978256649202535,
#  1.0,
#  0.88506840940021725,
#  0.77667677084322073,
#  0.79837307314842176,
#  0.99949361383914948,
#  0.60617837633384231,
#  0.75917973395843497,
#  0.99626482705051977,
#  1.0,
#  1.0,
#  0.76234686374664307,
#  0.85446940284748019,
#  0.83677468800808397,
#  0.99328253485939721,
#  0.99983988700916193,
#  1.0,
#  1.0,
#  1.0,
#  1.0,
#  0.66159323192745922,
#  0.81526149984813645,
#  0.94784018044182328,
#  0.80505300780059774,
#  0.66167178969389118,
#  1.0,
#  0.93866962134232035,
#  0.25277853012084961,
#  1.0,
#  0.2458624831316146,
#  1.0,
#  0.99994002598181297,
#  0.98276111125946042,
#  0.81032118862494829,
#  0.86238515660389725,
#  0.94669792753848769,
#  1.0,
#  0.46710560767113657,
#  0.877288108501449,
#  0.57701349488781728,
#  0.68629705905914307,
#  1.0,
#  0.5859638000795474,
#  0.79106222354373823,
#  0.59987568461205354,
#  0.54416630712027347,
#  0.10244452783084622,
#  0.021579172981482937,
#  0.094154171645641327,
#  1.0,
#  0.57338748580868637,
#  0.99999242634626306,
#  0.016177299793309938,
#  1.0,
#  1.0,
#  0.43526889332610569,
#  0.10244459019237721,
#  0.021579172981482937,
#  0.080780418589711189,
#  0.34503373076692662,
#  0.8799976752354548,
#  0.10244452783084622,
#  0.014220332839953508,
#  0.6813268594601205,
#  1.0,
#  0.4376977465988855,
#  0.012269248424656359,
#  0.039777879936554537,
#  0.36246064305305481,
#  0.21087618551176526,
#  1.0,
#  1.0,
#  0.99512932697931922,
#  0.99274958742075958,
#  0.999850866292886,

#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  0.2496967145143114,
#  0.0,
#  0.14543413142455286,
#  0.0,
#  0.009111247592072491,
#  0.0,
#  0.06073429645682249,
#  2.220446049250313e-16,
#  0.13196519519823724,
#  0.3815195989121527,
#  0.3139380440048214,
#  0.3882675946945535,
#  0.0,
#  0.24484081948055048,
#  0.0,
#  0.5275275800654367,
#  0.0,
#  -2.220446049250313e-16,
#  0.0,
#  0.0,
#  0.0,
#  0.006238683851893079,
#  0.07770487575588625,
#  0.015126720629552892,
#  0.012083349122267606,
#  0.22258107292739027,
#  0.34890353439290944,
#  0.15371001558491404,
#  0.34006963600169815,
#  0.088872067385803,
#  0.77184426806821,
#  0.21669479130614144,
#  0.048302239809367986,
#  0.26766274998106754,
#  0.42003373959536505,
#  0.34758325221015385,
#  0.0815879905172121,
#  0.16410041551242527,
#  0.22873797395142415,
#  0.23712632223258323,
#  0.0,
#  0.0,
#  0.0,
#  0.004325713640368933,
#  -4.440892098500626e-16,
#  0.05098380373040712,
#  0.0835389248623426,
#  0.17992718757068316]

# %%
import scipy.stats as stat

# %%
stat.describe(global_vis)
# Out:
# (64,
#  (-4.4408920985006262e-16, 0.77184426806821005),
#  0.11865994385546338,
#  0.025850877634130208,
#  1.635975881400208,
#  2.950770977873532)

# %%
stat.describe(surenesses)
# Out:
# (16,
#  (4.3715217523313832e-05, 0.97397554417451226),
#  0.27900002336034058,
#  0.094565285301165009,
#  0.7303908209742163,
#  -0.5717057734576874)

# %%
stat.describe(global_diff_vis)
# Out:
# (64,
#  (-0.062065295249726038, 0.96984706380368135),
#  0.39838652723219337,
#  0.056207523855086247,
#  0.3517143408715205,
#  -0.15519794111240248)

# %%
for SPLITS_NO in range(1,3):

#     SPLITS_NO = 5


    print 'For', SPLITS_NO, 'introduced splits per label'
    splits_diff_vis = []
    splits_vis = []
    splits_surenesses = []
    splits_before_vis = []
    for i,s in enumerate(global_splits):
        if s == SPLITS_NO:
            splits_diff_vis.append(global_diff_vis[i])
            splits_vis.append(global_vis[i])
            splits_surenesses.append(best_surenesses[i])
            splits_before_vis.append(global_before_vis[i])

    print 'Best avg. sureness', stat.describe(splits_surenesses)[2]
    print 'Best avg. VIs', stat.describe(splits_vis)[2]
    print 'Avg. beforeVI', stat.describe(splits_before_vis)[2]
    print 'Avg. (beforeVI - bestVI)', stat.describe(splits_diff_vis)[2]
    print 'Variance (beforeVI - bestVI)', stat.describe(splits_diff_vis)[3]
    print 'Median (beforeVI - bestVI)', np.median(splits_diff_vis)
    print '-'*80
# Out:
# For 1 introduced splits per label
# Best avg. sureness 0.13895080361
# Best avg. VIs 0.0800920125116
# Avg. beforeVI 0.404022707128
# Avg. (beforeVI - bestVI) 0.323930694617
# Variance (beforeVI - bestVI) 0.028918857352
# Median (beforeVI - bestVI) 0.360083079698
# --------------------------------------------------------------------------------
# For 2 introduced splits per label
# Best avg. sureness 0.177378600412
# Best avg. VIs 0.157227875199
# Avg. beforeVI 0.630070235047
# Avg. (beforeVI - bestVI) 0.472842359848
# Variance (beforeVI - bestVI) 0.0738643380738
# Median (beforeVI - bestVI) 0.486720484316
# --------------------------------------------------------------------------------
