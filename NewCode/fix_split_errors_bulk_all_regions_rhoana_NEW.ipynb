# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline


import cv2
import glob
import numpy as np
import mahotas as mh
import os
import uuid
import tifffile as tif
from scipy import ndimage as nd
from scipy.misc import imrotate
import skimage.measure
from skimage import img_as_ubyte
import random
import cPickle as pickle
import time
import partition_comparison
import copy
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

import _metrics

DATA_PATH = '/Volumes/DATA1/EMQM_DATA/ac3x75/'
GOLD_PATH = os.path.join(DATA_PATH,'gold/')
RHOANA_PATH = os.path.join(DATA_PATH,'rhoana/')
IMAGE_PATH = os.path.join(DATA_PATH,'input/')
PROB_PATH = os.path.join(DATA_PATH,'prob/')
PATCH_PATH = os.path.join(DATA_PATH,'test_rhoana/')
OUTPUT_PATH = '/Volumes/DATA1/bulk_split_errors/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fix_split_errors_new import *



val_fn = setup_n()
# Out:
# Loading ['/Volumes/DATA1/split_cnn/patches_3rd_small/a6d1924e-059c-4987-8512-da16a8d1aaee/configuration.txt']
# ["{'outputpath': '/Volumes/DATA1/split_cnn/patches_3rd_small/', 'uuid': 'a6d1924e-059c-4987-8512-da16a8d1aaee', 'filtersize1': 5, 'filters3': 32, 'filters2': 32, 'batchsize': 100, 'datapath': '/Volumes/DATA1/EMQM_DATA/ac3x75/', 'epochs': 20, 'runmode': 'local', 'filtersize2': 5, 'filtersize3': 5, 'filters1': 32, 'patchpath': 'patches_3rd_small', 'thirdconvlayer': False, 'learning_rate': 0.0001, 'momentum': 0.9}"]
# Loading ['/Volumes/DATA1/split_cnn/patches_3rd_small/a6d1924e-059c-4987-8512-da16a8d1aaee/network_19.p']

# %%
slices = [70,71,72,73,74]
splits_per_label = [1,2,3,4,5]

best_surenesses = []
bboxes = []
global_vis = []
global_before_vis = []
global_diff_vis = []
global_slices = []


for b in range(100,900,300):
    for b2 in range(100,900,300):
        
        BBOX = [b, b+200, b2, b2+200]

        for s in slices:
            gold = mh.imread(GOLD_PATH+'ac3_labels_00'+str(s)+'.tif')
            rhoana = mh.imread(RHOANA_PATH+os.sep+"z=000000"+str(s)+".tif")
            input_image = mh.imread(IMAGE_PATH+'ac3_input_00'+str(s)+'.tif')
            prob = mh.imread(PROB_PATH+'ac3_input_00'+str(s)+'_syn.tif')


            image = input_image[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]]
            prob = prob[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]]
            seg = _metrics.Util.normalize_labels(rhoana[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]])[0]



            # fill and normalize gold
            gold_zeros = _metrics.Util.threshold(gold[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]], 0)
            gold_filled = _metrics.Util.fill(gold[BBOX[0]:BBOX[1],BBOX[2]:BBOX[3]], gold_zeros.astype(np.bool))
            gold_filled_relabeled = skimage.measure.label(gold_filled).astype(np.uint64)
            gold_normalized = _metrics.Util.normalize_labels(gold_filled_relabeled)[0]

            # color both segmentations
            cm = _metrics.Util.load_colormap('/Volumes/DATA1/ac3x75/mojo/ids/colorMap.hdf5')
            colored_rhoana_normalized = cm[seg % len(cm)]
            colored_gold_normalized = cm[gold_normalized % len(cm)]

            gold_framed = np.array(gold_normalized)
            gold_framed[:38] = 0
            gold_framed[-38:] = 0
            gold_framed[:,0:38] = 0
            gold_framed[:,-38:] = 0
            #imshow(gold_framed)    

            image_framed = np.array(image)
            #imshow(image_framed,cmap='gray')    

#                 split_gold_normalized = create_spliterrors(image_framed, seg, splits).astype(np.uint64) #RHOANA
#                 split_gold_normalized = _metrics.Util.normalize_labels(split_gold_normalized)[0]
#                 colored_split_gold_normalized = cm[split_gold_normalized % len(cm)]
#                 split_gold_normalized_framed = np.array(split_gold_normalized)
            #imshow(split_gold_normalized.astype(np.uint64))    

            # RHOANA
            split_gold_normalized = seg
            split_gold_normalized_framed = np.array(split_gold_normalized)

            t0 = time.time()
            p = loop(image, prob, split_gold_normalized_framed)
            print len(p), 'patches generated in',time.time()-t0,'seconds'


            m_new = create_matrix(val_fn, split_gold_normalized_framed, p)

            t0 = time.time()
            out = split_gold_normalized_framed
            sureness = 0.


            surenesses = []
            vi_s = []
            _images = [out]

            before_VI = partition_comparison.variation_of_information(split_gold_normalized_framed.ravel(), gold_framed.ravel())

            while m_new.max() >= sureness:

                old_image = np.array(out)
                m_old = np.array(m_new)

                surenesses.append(m_new.max())    

                m_new, out, patches, l, n = merge(val_fn, image, out, prob, m_new)

                vi = partition_comparison.variation_of_information(out.ravel(), gold_framed.ravel())
                vi_s.append(vi)    



            # create plot
            index = vi_s.index(min(vi_s))
            out_text = 'Before VI ' + str(before_VI) + '\n'
            out_text += 'Lowest VI ' + str(vi_s[index]) + '\n'
            out_text += 'Iterations ' + str(index) + '\n'
            out_text += 'Sureness ' + str(surenesses[index]) + '\n'
            out_text += 'Ran in ' + str(time.time()-t0) + ' seconds\n'

            best_surenesses.append(surenesses[index])
            bboxes.append(BBOX)
            global_vis.append(vi_s[index])
            global_before_vis.append(before_VI)
            global_slices.append(s)
            global_diff_vis.append(before_VI - vi_s[index])
#                 global_splits.append(splits)

            new_rhoana = propagate_max_overlap(split_gold_normalized, gold_framed)
            target_vi = partition_comparison.variation_of_information(new_rhoana.ravel(), gold_framed.ravel())

            bins = np.arange(0, len(vi_s))#np.arange(len(vi_s), 0, -1)
            # bins /= 100

            vi_s_ = vi_s #[x for (y,x) in sorted(zip(surenesses, vi_s))]
            surenesses_ = bins #surenesses#[y for (y,x) in sorted(zip(surenesses, vi_s))]

            original_vi = [before_VI]*len(vi_s)
            target_vi = [target_vi]*len(vi_s)

            fig, ax = plt.subplots()
            fig.text(0,1,'\n\n\n\n\n'+out_text)

            ax.plot(surenesses_, target_vi, 'k--', label='Target VI')
            ax.plot(surenesses_, vi_s_, 'k', label='Variation of Information')
            ax.plot(surenesses_, original_vi, 'k:', label='VI before')
            # ax.set_yscale('log')

            # Now add the legend with some customizations.
            legend = ax.legend(loc='upper center', shadow=True)
            ax.set_ylim([-0.5,1.5])

            # The frame is matplotlib.patches.Rectangle instance surrounding the legend.
            frame = legend.get_frame()
            frame.set_facecolor('0.90')

            # Set the fontsize
            for label in legend.get_texts():
                label.set_fontsize('large')

            for label in legend.get_lines():
                label.set_linewidth(1.5)  # the legend line width

            plt.savefig(OUTPUT_PATH+os.sep+'result'+str(s)+'.png')
# Out:
# 236 patches generated in 3.21465992928 seconds
# 242
#  patches generated in 3.13655304909 seconds
# 246
#  patches generated in 3.13667678833 seconds
# 212
#  patches generated in 2.66212320328 seconds
# 354
#  patches generated in 4.35353708267 seconds
# 580
#  patches generated in 6.48410701752 seconds
# 456
#  patches generated in 5.32850003242 seconds
# 626
#  patches generated in 7.21528601646 seconds
# 406
#  patches generated in 4.89994812012 seconds
# 376
#  patches generated in 4.51966404915 seconds
# 274
#  patches generated in 3.63229203224 seconds
# 78
#  patches generated in 1.17651104927 seconds
# 68
#  patches generated in 1.0470430851 seconds
# 50
#  patches generated in 0.848433971405 seconds
# 142
#  patches generated in 1.90640687943 seconds
# 8
#  patches generated in 0.243422985077 seconds
# 4
#  patches generated in 0.176477909088 seconds
# 14
#  patches generated in 0.34574007988 seconds
# 48
#  patches generated in 0.826207876205 seconds
# 10
#  patches generated in 0.32639503479 seconds
# 256
#  patches generated in 3.41563510895 seconds
# 306
#  patches generated in 4.09887599945 seconds
# 220
#  patches generated in 3.1482000351 seconds
# 260
#  patches generated in 3.61803102493 seconds
# 224
#  patches generated in 3.04093599319 seconds
# 818
#  patches generated in 8.83742690086 seconds
# 1006
#  patches generated in 11.1309709549 seconds
# 894
#  patches generated in 9.66379404068 seconds
# 630
#  patches generated in 7.11506104469 seconds
# 810
#  patches generated in 8.97349214554 seconds
# 502
#  patches generated in 6.01207709312 seconds
# 610
#  patches generated in 6.97549510002 seconds
# 590
#  patches generated in 6.63034510612 seconds
# 632
#  patches generated in 7.09572219849 seconds
# 634
#  patches generated in 6.95024681091 seconds
# 272
#  patches generated in 3.42911505699 seconds
# 296
#  patches generated in 3.9214630127 seconds
# 266
#  patches generated in 3.33560109138 seconds
# 398
#  patches generated in 4.6207780838 seconds
# 274
#  patches generated in 3.4148747921 seconds
# 170
#  patches generated in 2.39596104622 seconds
# 156
#  patches generated in 2.22153496742 seconds
# 342
#  patches generated in 4.33108711243 seconds
# 492
#  patches generated in 5.78294491768 seconds
# 458
#  patches generated in 5.5730509758 seconds

# %%
global_vis
# Out:
# [0.8097099480822736,
#  0.52526963985702,
#  0.35138747866832354,
#  0.40161007952355376,
#  0.42017502014179775,
#  0.6320019872413729,
#  0.5099657925933836,
#  0.6240345258595013,
#  0.49956609044812783,
#  0.6352572406338282,
#  0.9533330423123263,
#  0.8773467075784097,
#  0.5533537265272457,
#  0.1814470151905152,
#  0.18479965308788704,
#  0.03890345262874757,
#  0.032549066161437004,
#  0.029603843785335593,
#  0.03443821518115975,
#  0.03759625568722852,
#  0.33858609491322444,
#  0.30548540707645744,
#  0.4342386529733562,
#  0.5435330602272996,
#  0.3504671360870748,
#  1.2017240245737066,
#  1.2758426567171375,
#  1.3648539082894926,
#  1.2560251606380373,
#  1.3236982134285395,
#  0.5544599286308229,
#  0.6846842466197871,
#  0.5377410403555976,
#  0.9846468768109817,
#  0.8411408303502639,
#  0.28835673165615816,
#  0.41456672645213777,
#  0.4038615878473779,
#  0.45420769762759283,
#  0.40079738822728306,
#  0.39620473057672245,
#  0.47429512900028925,
#  0.3751149477498932,
#  0.6265156069764899,
#  0.76577286034671]

# %%
global_diff_vis
# Out:
# [-0.06064904281920236,
#  -0.01947180298554141,
#  -0.011738944193169232,
#  0.004639761475721649,
#  0.11044038299066128,
#  0.007588549512432596,
#  0.015975936110137923,
#  0.030375023196233197,
#  0.015239383581520105,
#  -0.10668562579295537,
#  0.14257356309605362,
#  -0.042088303577899056,
#  -0.04123803882495736,
#  0.0005621716252797171,
#  0.0819503809438491,
#  -0.0022610154062193896,
#  -0.023441491947402145,
#  0.0016584421132651017,
#  0.013145353580503345,
#  -0.002670087188709286,
#  0.0,
#  0.02162205567083486,
#  -0.15618087198836594,
#  -0.15036124578386167,
#  0.006654907773464114,
#  -0.01622072843942224,
#  0.09157169806838228,
#  -0.05095709391546155,
#  -0.009821890919988974,
#  0.13932717847801168,
#  0.11979044449369436,
#  0.030070525385700986,
#  0.029940443117956406,
#  -0.27606688817173364,
#  0.004125317034209264,
#  -0.00034598738374436167,
#  0.019367162247331038,
#  0.0,
#  0.0021862341788638773,
#  -0.0016609695033187322,
#  -0.078001090836189,
#  -0.08505176035094486,
#  0.36617365951741165,
#  0.32890744760085333,
#  0.035497316450207705]

# %%
import scipy.stats as stat

# %%
stat.describe(global_vis)
# Out:
# (45,
#  (0.026748943221719629, 1.4868989348058368),
#  0.56645596634719608,
#  0.11805637962934665,
#  0.7181672098238547,
#  0.6019094285383888)

# %%
stat.describe(global_diff_vis)
# Out:
# (45,
#  (-0.27606688817173364, 0.36617365951741165),
#  0.010766010182522059,
#  0.010981160992225207,
#  0.9603080346510848,
#  3.8812612391949095)
