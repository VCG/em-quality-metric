# %%
# %load_ext autoreload
# %autoreload 2

from cnn import CNN
from util import Util
from patch import Patch
from fixer import Fixer
from uglify import Uglify

import mahotas as mh
import numpy as np

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is disabled)
# tifffile.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)

# %%
SLICE = 70
# zeros are ignored during patch generation!
input_image, input_prob, input_gold, input_rhoana = Util.read_section(SLICE, keep_zeros=True)

# %%
Util.view(input_gold, large=True)

# %%
Util.view(input_rhoana, large=True)

# %%
rhoana_fixed = Util.propagate_max_overlap(input_rhoana, input_gold)
print rhoana_fixed.min()
# Out:
# 0

# %%
rhoana_fixed = Util.relabel(rhoana_fixed)

# %%
Util.view(rhoana_fixed, large=True)

# %%
rhoana_fixed.min()
# Out:
# 0

# %%
Util.vi(rhoana_fixed, input_gold)
# Out:
# 0.38101265613489943

# %%
Util.vi(input_rhoana, input_gold)
# Out:
# 0.517206002804862

# %%
rhoana_borders = mh.labeled.borders(input_rhoana)
rhoana_fixed_borders = mh.labeled.borders(rhoana_fixed)

# %%
Util.view(rhoana_borders, large=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5b6d1b894c1> in <module>()
# ----> 1 Util.view(rhoana_borders, large=True)
#
# NameError: name 'Util' is not defined

# %%
Util.view(rhoana_fixed_borders, large=True)

# %%
gold_borders = mh.labeled.borders(input_gold)

# %%
Util.view(gold_borders, large=True)

# %%
diff_borders = rhoana_borders-rhoana_fixed_borders

# %%
Util.view(diff_borders, large=True)

# %%
import time
t0 = time.time()
error_patches, patches = Patch.patchify_maxoverlap(input_image, input_prob, input_rhoana, input_gold)
print time.time()-t0
# Out:
# 325.491835117

# %%
len(error_patches)
# Out:
# 13560

# %%
len(patches)
# Out:
# 14276

# %%
np.mean(Util.get_histogram(rhoana_fixed))
# Out:
# 3705.2155477031802

# %%
missing_error_patches = len(patches)-len(error_patches)

# %%
t0 = time.time()
new_error_patches = Uglify.split_and_patchify(input_image, input_prob, rhoana_fixed, 
                                              min_pixels=1000, max=missing_error_patches, 
                                              n=10, sample_rate=10, oversampling=True, patch_size=(31,31))
print time.time()-t0
# Out:
# 86.0017910004

# %%
len(new_error_patches)
# Out:
# 6258

# %%
aaa = error_patches + new_error_patches

# %%
len(aaa)

# %%
error_patches[0]['l']
# Out:
# 14

# %%
error_patches[0]['n']
# Out:
# 103

# %%
patches_l, patches_n = Patch.grab(input_image, input_prob, input_rhoana, 14, 103, patch_size=(31,31))

# %%
len(patches_n)
# Out:
# 1

# %%
1024*1024*75
# Out:
# 78643200

# %%
65*372
# Out:
# 24180

# %%
Patch.show(new_error_patches[20:30])

# %%
Util.view(mh.dilate(diff_borders), large=True)

# %%
border_comp = np.zeros(diff_borders.shape, dtype=np.uint8)
border_comp[diff_borders==1] = 1
border_comp[gold_borders==1] += 1
print border_comp.max()
Util.view(border_comp, large=True)
# Out:
# 2

# %%
Util.view(Util.threshold(border_comp,2).astype(np.bool),large=True)

# %%
cnn_viren = CNN('viren_large_200', 'patches_4th', ['image','prob','merged_array', 'dyn_obj', 'dyn_bnd', 'larger_border_overlap'])
cnn = CNN('d09fc48f-b3ec-40b0-bc38-98863eb9c95f', 'patches_4th')
cnn_mine = CNN('mine', 'patches_4th')
cnn_large = CNN('0b42dcbc-f1d9-42e2-8e2d-cf6b64a8cf76', 'patches_4th', ['image', 'prob', 'binary', 'larger_border_overlap'])
# Out:
# Loading ['/Volumes/DATA1/split_cnn/patches_4th/viren_large_200/configuration.txt']
# Loading ['/Volumes/DATA1/split_cnn/patches_4th/viren_large_200/network_76.p']
# Loading
#  ['/Volumes/DATA1/split_cnn/patches_4th/d09fc48f-b3ec-40b0-bc38-98863eb9c95f/configuration.txt']
# Loading ['/Volumes/DATA1/split_cnn/patches_4th/d09fc48f-b3ec-40b0-bc38-98863eb9c95f/network_99.p']
# Loading
#  ['/Volumes/DATA1/split_cnn/patches_4th/mine/configuration.txt']
# Loading ['/Volumes/DATA1/split_cnn/patches_4th/mine/network_141.p']
# Loading
#  ['/Volumes/DATA1/split_cnn/patches_4th/0b42dcbc-f1d9-42e2-8e2d-cf6b64a8cf76/configuration.txt']
# Loading ['/Volumes/DATA1/split_cnn/patches_4th/0b42dcbc-f1d9-42e2-8e2d-cf6b64a8cf76/network_9.p']

# %%
Util.view_labels(input_rhoana, 167)

# %%
patches = Patch.grab_single(input_image, input_prob, input_rhoana, 167)

# %%
len(patches)
# Out:
# 3

# %%
print Patch.test_and_unify(patches, cnn)
print Patch.test_and_unify(patches, cnn_mine)
print Patch.test_and_unify(patches, cnn_large)
print Patch.test_and_unify(patches, cnn_viren)
# Out:
# 0.999946394901
# 0.995839864561
# 0.993347696441
# 0.361685500535

# %%
input_rhoana[450,500]
# Out:
# 148

# %%
Util.view_labels(input_rhoana, 148)

# %%
patches = Patch.grab_single(input_image, input_prob, input_rhoana, 148)

# %%
print Patch.test_and_unify(patches, cnn)
print Patch.test_and_unify(patches, cnn_large)
print Patch.test_and_unify(patches, cnn_viren)
# Out:
# 0.999879838049
# 0.973315911827
# 0.461327844677

# %%
print Patch.grab_group_test_and_unify(cnn, input_image, input_prob, input_rhoana, 167, 148)
print Patch.grab_group_test_and_unify(cnn_large, input_image, input_prob, input_rhoana, 167, 148)
print Patch.grab_group_test_and_unify(cnn_viren, input_image, input_prob, input_rhoana, 167, 148)
# Out:
# 6.23935209054e-10
# 5.21401877229e-09
# 3.58407548084e-09

# %%
Util.grab_neighbors(input_rhoana, 167)
# Out:
# array([140, 148, 159, 164, 168, 178, 189, 201])

# %%
for n in Util.grab_neighbors(input_rhoana, 167):
    print Patch.grab_group_test_and_unify(cnn, input_image, input_prob, input_rhoana, 167, n)
    print Patch.grab_group_test_and_unify(cnn_large, input_image, input_prob, input_rhoana, 167, n)
    print Patch.grab_group_test_and_unify(cnn_viren, input_image, input_prob, input_rhoana, 167, n)
    print Patch.grab_group_test_and_unify(cnn_mine, input_image, input_prob, input_rhoana, 167, n)
    print '-'*80
# Out:
# 0.114423580816
# 0.222609487271
# 0.00760701949208
# 0.0931798820899
# --------------------------------------------------------------------------------
# 6.23935209054e-10
# 5.21401877229e-09
# 3.58407548084e-09
# 1.17873162253e-06
# --------------------------------------------------------------------------------
# 0.031871041283
# 0.00141655514017
# 1.05355434243e-06
# 0.0133130643517
# --------------------------------------------------------------------------------
# 6.68518734294e-12
# 1.70233369068e-09
# 4.77052841674e-09
# 4.91800067337e-08
# --------------------------------------------------------------------------------
# 0.00180513219675
# 0.127091500908
# 3.52273309545e-06
# 0.0451702270657
# --------------------------------------------------------------------------------
# 8.83424782216e-08
# 1.12082670967e-06
# 4.79079826619e-05
# 3.81929075957e-05
# --------------------------------------------------------------------------------
# 4.73048628047e-10
# 5.08654673936e-09
# ...

# %%
input_rhoana[650,175]
# Out:
# 235

# %%
Util.view_labels(input_rhoana, 235)

# %%
for n in Util.grab_neighbors(input_rhoana, 235):
    print n
    print Patch.grab_group_test_and_unify(cnn, input_image, input_prob, input_rhoana, 235, n, sample_rate=10, oversampling=True)
    print Patch.grab_group_test_and_unify(cnn_large, input_image, input_prob, input_rhoana, 235, n, sample_rate=10, oversampling=True)
    print Patch.grab_group_test_and_unify(cnn_viren, input_image, input_prob, input_rhoana, 235, n, sample_rate=10, oversampling=True)
    print Patch.grab_group_test_and_unify(cnn_mine, input_image, input_prob, input_rhoana, 235, n, sample_rate=10, oversampling=True)
    print '-'*80
# Out:
# 14
# 4.38340401977e-05
# 1.7663909059e-05
# 1.68652996546e-06
# 1.89546776591e-05
# --------------------------------------------------------------------------------
# 205
# 1.12408640875e-06
# 7.04480803915e-09
# 2.5029152075e-08
# 8.84784300344e-07
# --------------------------------------------------------------------------------
# 229
# 0.494084577154
# 0.00220749003408
# 0.00395629698537
# 0.0780777490387
# --------------------------------------------------------------------------------
# 234
# 5.85150375868e-05
# 0.000345466489495
# 0.000546090255046
# 0.00154760119335
# --------------------------------------------------------------------------------
# 241
# 1.35011016348e-06
# 2.19795773102e-05
# 0.000138466320565
# 2.24421820199e-05
# --------------------------------------------------------------------------------
# 242
# 0.00061864247072
# 4.23688506955e-05
# 0.00347293722785
# 0.0106056805788
# --------------------------------------------------------------------------------
# ...

# %%
Util.view_labels(input_rhoana, [235,249])

# %%
print Patch.grab_group_test_and_unify(cnn, input_image, input_prob, input_rhoana, 235, 229, oversampling=True)
print Patch.grab_group_test_and_unify(cnn_large, input_image, input_prob, input_rhoana, 235, 229, oversampling=True)
print Patch.grab_group_test_and_unify(cnn_viren, input_image, input_prob, input_rhoana, 235, 229, oversampling=True)
# Out:
# 0.494084577154
# 0.00220749003408
# 0.00395629698537

# %%
print Patch.grab_group_test_and_unify(cnn, input_image, input_prob, input_rhoana, 235, 249)
print Patch.grab_group_test_and_unify(cnn_large, input_image, input_prob, input_rhoana, 235, 249)
print Patch.grab_group_test_and_unify(cnn_viren, input_image, input_prob, input_rhoana, 235, 249)
print Patch.grab_group_test_and_unify(cnn_mine, input_image, input_prob, input_rhoana, 235, 249)
# Out:
# 0.974118173122
# 0.961649060249
# 0.0147242732346
# 0.989304959774

# %%
print Patch.grab_group_test_and_unify(cnn, input_image, input_prob, input_rhoana, 235, 249 , sample_rate=-1, oversampling=True)
print Patch.grab_group_test_and_unify(cnn_large, input_image, input_prob, input_rhoana, 235, 249 , sample_rate=-1, oversampling=True)
print Patch.grab_group_test_and_unify(cnn_viren, input_image, input_prob, input_rhoana, 235, 249 , sample_rate=-1, oversampling=True)
print Patch.grab_group_test_and_unify(cnn_mine, input_image, input_prob, input_rhoana, 235, 249 , sample_rate=-1, oversampling=True)
# Out:
# 0.381081612545
# 0.230769557586
# 0.00482943320381
# 0.446566215701

# %%
p_l, p_n = Patch.grab(input_image, input_prob, input_rhoana, 235, 229)

# %%
Patch.show(p_l, cnn, 0)

# %%
Util.view_labels(input_rhoana, [235,14, 205, 229, 234, 241, 242, 249])

# %%
LABEL = 235
SAMPLE_RATE = -1
OVERSAMPLING = True

# view_labels = Util.view_labels(input_rhoana, [LABEL]+list(Util.grab_neighbors(input_rhoana, LABEL)), crop=False, return_it=True)

cnn_out = np.zeros((view_labels.shape[0], view_labels.shape[1], 3), dtype=np.uint8)
cnn_out[:,:,0] = input_image[:,:]
cnn_out[:,:,1] = input_image[:,:]
cnn_out[:,:,2] = input_image[:,:]

cnn_large_out = np.array(cnn_out)
cnn_viren_out = np.array(cnn_out)
cnn_mine_out = np.array(cnn_out)

for n in Util.grab_neighbors(input_rhoana, LABEL):

    pred_cnn = Patch.grab_group_test_and_unify(cnn, input_image, input_prob, input_rhoana, LABEL, n , sample_rate=SAMPLE_RATE, oversampling=OVERSAMPLING)
    pred_cnn_large = Patch.grab_group_test_and_unify(cnn_large, input_image, input_prob, input_rhoana, LABEL, n , sample_rate=SAMPLE_RATE, oversampling=OVERSAMPLING)
    pred_cnn_viren = Patch.grab_group_test_and_unify(cnn_viren, input_image, input_prob, input_rhoana, LABEL, n , sample_rate=SAMPLE_RATE, oversampling=OVERSAMPLING)
    pred_cnn_mine = Patch.grab_group_test_and_unify(cnn_mine, input_image, input_prob, input_rhoana, LABEL, n , sample_rate=SAMPLE_RATE, oversampling=OVERSAMPLING)
    
    border = mh.labeled.border(input_rhoana, LABEL, n)
    cnn_out[border==1] = (pred_cnn*255,0,0)
    cnn_large_out[border==1] = (pred_cnn_large*255,0,0)
    cnn_viren_out[border==1] = (pred_cnn_viren*255,0,0)
    cnn_mine_out[border==1] = (pred_cnn_mine*255,0,0)
#     if pred_cnn > .5:
#         cnn_out[border == 1] = (255,0,0)
#     else:
#         cnn_out[border == 1] = (0,255,0)
        
#     if pred_cnn_large > .5:
#         cnn_large_out[border == 1] = (255,0,0)
#     else:
#         cnn_large_out[border == 1] = (0,255,0)

#     if pred_cnn_viren > .5:
#         cnn_viren_out[border == 1] = (255,0,0)
#     else:
#         cnn_viren_out[border == 1] = (0,255,0)

# %%
# sample rate 1
# no oversampling
plt.figure()
imshow(cnn_out[500:700,80:220])
plt.figure()
imshow(cnn_large_out[500:700,80:220])
plt.figure()
imshow(cnn_viren_out[500:700,80:220])
plt.figure()
imshow(cnn_mine_out[500:700,80:220])

# %%
# sample rate 10
# no oversampling
plt.figure()
imshow(cnn_out[500:700,80:220])
plt.figure()
imshow(cnn_large_out[500:700,80:220])
plt.figure()
imshow(cnn_viren_out[500:700,80:220])

# %%
# sample rate 10
# yes oversampling
plt.figure()
imshow(cnn_out[500:700,80:220])
plt.figure()
imshow(cnn_large_out[500:700,80:220])
plt.figure()
imshow(cnn_viren_out[500:700,80:220])

# %%
Util.view(input_rhoana[500:700,80:220])

# %%
Util.view(input_gold[500:700,80:220])

# %%
from stats import Stats

# %%
Stats.create('viren_7', 'patches_7th', ['image', 'prob', 'merged_array'])
# Out:
# Loading ['/Volumes/DATA1/split_cnn/patches_7th/viren_7/configuration.txt']
# Loading /Volumes/DATA1/split_cnn/patches_7th/viren_7/network_90.p
# Performing split test..
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70]
#   Oversampling: False
#   Merge smallest first: False
#   No. splits to uglify: 2
#   Keep zeros in segmentation: True
# VI:
#   N:  1
#   Min:  0.164530494098
#   Max:  0.164530494098
#   Mean:  0.164530494098
#   Median:  0.164530494098
#   Std:  0.0
#   Var:  0.0
# VI before-after:
#   N:  1
#   Min:  0.362756027912
#   Max:  0.362756027912
#   Mean:  0.362756027912
#   Median:  0.362756027912
#   Std:  0.0
#   Var:  0.0
# Surenesses:
#   N:  1
#   Min:  0.649553923316
#   Max:  0.649553923316
#   Mean:  0.649553923316
#   Median:  0.649553923316
#   Std:  0.0
#   Var:  0.0
# ...
