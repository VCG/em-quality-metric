# %%
# %load_ext autoreload
# %autoreload 2

from cnn import CNN
from experiment import Experiment
from util import Util
from patch import Patch
from fixer import Fixer
from uglify import Uglify

import mahotas as mh
import numpy as np

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cnn_viren = CNN('viren_large_200', 'patches_4th', ['image','prob','merged_array', 'dyn_obj', 'dyn_bnd', 'larger_border_overlap'])
cnn = CNN('d09fc48f-b3ec-40b0-bc38-98863eb9c95f', 'patches_4th')
cnn_mine = CNN('mine', 'patches_4th')
cnn_viren2 = CNN('viren_overlap', 'patches_4th', ['image', 'prob', 'merged_array', 'dyn_obj', 'dyn_bnd', 'border_overlap'])
cnn_rhoana_new = CNN('dcb5cb86-7e51-4a52-bb3f-bbb1195036fa', 'patches_6th')
cnn_large = CNN('0b42dcbc-f1d9-42e2-8e2d-cf6b64a8cf76', 'patches_4th', ['image', 'prob', 'binary', 'larger_border_overlap'])
# Out:
# Loading ['/Volumes/DATA1/split_cnn/patches_4th/viren_large_200/configuration.txt']
# Loading /Volumes/DATA1/split_cnn/patches_4th/viren_large_200/network_76.p
# Loading
#  ['/Volumes/DATA1/split_cnn/patches_4th/d09fc48f-b3ec-40b0-bc38-98863eb9c95f/configuration.txt']
# Loading /Volumes/DATA1/split_cnn/patches_4th/d09fc48f-b3ec-40b0-bc38-98863eb9c95f/network_99.p
# Loading
#  ['/Volumes/DATA1/split_cnn/patches_4th/mine/configuration.txt']
# Loading /Volumes/DATA1/split_cnn/patches_4th/mine/network_141.p
# Loading
#  ['/Volumes/DATA1/split_cnn/patches_4th/viren_overlap/configuration.txt']
# Loading /Volumes/DATA1/split_cnn/patches_4th/viren_overlap/network_121.p
# Loading
#  ['/Volumes/DATA1/split_cnn/patches_6th/dcb5cb86-7e51-4a52-bb3f-bbb1195036fa/configuration.txt']
# Loading /Volumes/DATA1/split_cnn/patches_6th/dcb5cb86-7e51-4a52-bb3f-bbb1195036fa/network_20.p
# Loading
#  ['/Volumes/DATA1/split_cnn/patches_4th/0b42dcbc-f1d9-42e2-8e2d-cf6b64a8cf76/configuration.txt']
# Loading /Volumes/DATA1/split_cnn/patches_4th/0b42dcbc-f1d9-42e2-8e2d-cf6b64a8cf76/network_9.p

# %%
SLICE = 70
input_image, input_prob, input_gold, input_rhoana = Util.read_section(SLICE, keep_zeros=)

# %%
framed_gold = Util.frame_image(input_gold, shape=(200,200))

# %%
Util.view(framed_gold, large=True)

# %%
bins_mine_keepzeros = []
bins_mins_nozeros = []
bins_viren_large_keepzeros = []
bins_viren_large_nozeros = []
bins_rhoana_keepzeros = []
bins_rhoana_nozeros = []

for i in range(5):
    vi_diffs, bins = Experiment.run_merge_test(cnn_mine, keep_zeros=True)
    bins_mine_keepzeros.append(bins)
for i in range(5):
    vi_diffs, bins = Experiment.run_merge_test(cnn_mine, keep_zeros=False)
    bins_mins_nozeros.append(bins)

for i in range(5):
    vi_diffs, bins = Experiment.run_merge_test(cnn_viren2, keep_zeros=True)
    bins_viren_large_keepzeros.append(bins)
for i in range(5):
    vi_diffs, bins = Experiment.run_merge_test(cnn_viren2, keep_zeros=False)
    bins_viren_large_nozeros.append(bins)

for i in range(5):
    vi_diffs, bins = Experiment.run_merge_test(cnn_rhoana_new, keep_zeros=True)
    bins_rhoana_keepzeros.append(bins)
for i in range(5):
    vi_diffs, bins = Experiment.run_merge_test(cnn_rhoana_new, keep_zeros=False)
    bins_rhoana_nozeros.append(bins)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: True
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# New Experiment:
#   Data: gt
#   Slices: [70, 71, 72, 73, 74]
#   No. splits for borders: 20
#   Keep zeros in segmentation: False

# %%
bins_rhoana_keepzeros
# Out:
# [[0.12012753032860993,
#   0.0948524738392694,
#   0.07948013853664798,
#   0.11033961160155283,
#   0.10382745167460997],
#  [0.10224680579881075,
#   0.08779214476155363,
#   0.113690271671487,
#   0.12570503551701645,
#   0.12071640845972872],
#  [0.07925557323584534,
#   0.11105987969937799,
#   0.11655339371595706,
#   0.12974399044243246,
#   0.11218523597127593],
#  [0.10143593342658991,
#   0.09442837984275215,
#   0.11815674324504931,
#   0.10236173448803805,
#   0.12384564514695132],
#  [0.09727269592121228,
#   0.08999484224354828,
#   0.0803457513862575,
#   0.10788797038141368,
#   0.09535501184361232]]

# %%
bins_rhoana_keepzeros20 = []
for i in range(5):
    vi_diffs, bins = Experiment.run_merge_test(cnn_rhoana_new, keep_zeros=True)
    bins_rhoana_keepzeros20.append(bins)

# %%
bins
# Out:
# [-0.08814364155543764,
#  -0.0484638523828692,
#  -0.029961208394160287,
#  0.0015104957789247322,
#  -0.02393672069312095]

# %%
label1 = 205#framed_gold[600,600]
label2 = 199#framed_gold[750,600]




cropped_image, cropped_prob, cropped_segmentation, cropped_binary, bbox = Uglify.merge_label(input_image,
                                                                                       input_prob,
                                                                                       framed_gold,
                                                                                       label1,
                                                                                       label2,
                                                                                       
                                                                                       crop=False)

borders, best_border_image, result, result_no_border = Fixer.fix_single_merge(cnn_viren, cropped_image, cropped_prob, cropped_binary,erode=True)

Util.view_labels(framed_gold, [label1, label2])
Util.view_labels(cropped_segmentation, [label1])
Util.view(result, large=True, crop=True)
# Out:
# new best 4 8.76819874485e-07
# new best
#  4 1.7920003091e-18

# %%
Util.view(result, large=True, crop=False)

# %%
Util.view(borders, large=True, crop=False, color=False)

# %%
cropped_image, cropped_prob, cropped_segmentation, cropped_binary, bbox = Uglify.merge_label(input_image,
                                                                                       input_prob,
                                                                                       framed_gold,
                                                                                       280,
                                                                                       240,
                                                                                       crop=True)

borders, best_border_image, result = Fixer.fix_single_merge(cnn, cropped_image, cropped_prob, cropped_binary, N=10, debug=True)
# Out:
# 0 161
# 1
#  1219
# new best
#  1 0.781365253098
# 2
#  751
# new best
#  2 0.0045809451843
# 3
#  1247
# 4
#  223
# 5
#  132
# 6
#  859
# 7
#  104
# 8
#  370
# 9
#  859

# %%
Util.view_labels(framed_gold, [280, 240])
Util.view_labels(cropped_segmentation, [280])
Util.view(best_border_image, large=True, crop=True)
Util.view(result, large=True, crop=True)

# %%
Util.view_labels(cropped_segmentation, [83])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-937805a67a4a> in <module>()
# ----> 1 Util.view_labels(cropped_segmentation, [83])
#
# /Users/d/Projects/em-quality-metric/Reignite/util.py in view_labels(array, labels, crop, large)
#      66     fig = plt.figure(figsize=figsize)
#      67
# ---> 68     plt.imshow(out)
#      69
#      70     # return out
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, **kwargs)
#    2375         ax.hold(hold)
#    2376     try:
# -> 2377         ret = ax.imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    2378         draw_if_interactive()
#    2379     finally:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    6805             im.set_clim(vmin, vmax)
#    6806         else:
# -> 6807             im.autoscale_None()
#    6808         im.set_url(url)
#    6809
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/cm.pyc in autoscale_None(self)
#     281         if self._A is None:
#     282             raise TypeError('You must first set_array for mappable')
# --> 283         self.norm.autoscale_None(self._A)
#     284         self.changed()
#     285
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/colors.pyc in autoscale_None(self, A)
#     889         ' autoscale only None-valued vmin or vmax'
#     890         if self.vmin is None:
# --> 891             self.vmin = ma.min(A)
#     892         if self.vmax is None:
#     893             self.vmax = ma.max(A)
#
# /Library/Python/2.7/site-packages/numpy/ma/core.pyc in min(obj, axis, out, fill_value)
#    6212 def min(obj, axis=None, out=None, fill_value=None):
#    6213     try:
# -> 6214         return obj.min(axis=axis, fill_value=fill_value, out=out)
#    6215     except (AttributeError, TypeError):
#    6216         # If obj doesn't have a min method or if the method doesn't accept
#
# /Library/Python/2.7/site-packages/numpy/ma/core.pyc in min(self, axis, out, fill_value)
#    5406         if out is None:
#    5407             result = self.filled(fill_value).min(
# -> 5408                 axis=axis, out=out).view(type(self))
#    5409             if result.ndim:
#    5410                 # Set the mask
#
# /Library/Python/2.7/site-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
imshow(best_border_image,cmap='gray')

# %%
l = 329
n = 382

before_merge_error = np.zeros(framed_gold.shape)
before_merge_error[framed_gold == l] = 1
before_merge_error[framed_gold == n] = 2
before_merge_error = mh.croptobbox(before_merge_error)


cropped_image, cropped_prob, cropped_segmentation, cropped_binary, bbox = Uglify.merge_label(input_image,
                                                                                       input_prob,
                                                                                       framed_gold,
                                                                                       l,
                                                                                       n,
                                                                                       crop=True)

print 'VI after merge error:', Util.vi(before_merge_error.astype(np.uint8), mh.croptobbox(cropped_binary).astype(np.uint8))

borders, best_border_image, result, result_no_border = Fixer.fix_single_merge(cnn_mine, cropped_image,
                                                                              cropped_prob,
                                                                              cropped_binary,
                                                                              N=20,
                                                                              erode=True,
                                                                              before_merge_error=before_merge_error)

print 'VI after fixing:', Util.vi(before_merge_error.astype(np.uint8), mh.croptobbox(result_no_border).astype(np.uint8))
print '-'*80
# Out:
# VI after merge error: 0.677069766781
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23677474731e-06
# vi 0.0622695638752
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23677474731e-06
# vi 0.0622695638752
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# new best
#  4 4.23634169806e-06
# vi 0.0233092737086
# VI after fixing: 0.0233092737086
# --------------------------------------------------------------------------------

# %%
imshow(before_merge_error)

# %%
imshow( mh.croptobbox(result_no_border))

# %%
mh.croptobbox(result_no_border).shape
# Out:
# (257, 144)

# %%
before_merge_error.shape
# Out:
# (257, 144)

# %%
Util.vi(before_merge_error.astype(np.uint8), mh.croptobbox(result_no_border).astype(np.uint8))
# Out:
# 0.023309273708584488

# %%
imshow(mh.croptobbox(cropped_binary).astype(np.uint8))

# %%
label1 = framed_gold[600,600]
label2 = framed_gold[750,600]

# %%
label1,label2
# Out:
# (329, 382)

# %%
(1,2) - (5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-83798df45a6b> in <module>()
# ----> 1 (1,2) - (5,6)
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
map(operator.sub, (1,2), (5,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1f1ce42a7e8f> in <module>()
# ----> 1 map(operator.sub, (1,2), (5,6))
#
# NameError: name 'operator' is not defined

# %%
map(int.__sub__, (1,2), (5,6))
# Out:
# [-4, -4]

# %%
aaa = np.zeros((10,10))

# %%
aaa.shape
# Out:
# (10, 10)

# %%
np.pad(aaa, -1, mode='minimum').shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-d232b763805c> in <module>()
# ----> 1 np.pad(aaa, -1, mode='minimum').shape
#
# /Library/Python/2.7/site-packages/numpy/lib/arraypad.pyc in pad(array, pad_width, mode, **kwargs)
#    1316
#    1317     narray = np.array(array)
# -> 1318     pad_width = _validate_lengths(narray, pad_width)
#    1319
#    1320     allowedkwargs = {
#
# /Library/Python/2.7/site-packages/numpy/lib/arraypad.pyc in _validate_lengths(narray, number_elements)
#    1107         if (chk[0] < 0) or (chk[1] < 0):
#    1108             fmt = "%s cannot contain negative values."
# -> 1109             raise ValueError(fmt % (number_elements,))
#    1110     return normshp
#    1111
#
# ValueError: -1 cannot contain negative values.
