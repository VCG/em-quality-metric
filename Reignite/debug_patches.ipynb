# %%
# %load_ext autoreload
# %autoreload 2

from cnn import CNN
from util import Util

from patch import Patch
import mahotas as mh
import numpy as np

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is disabled)

# %%
cnn = CNN('8b33e516-2311-4892-82f9-4e6079c261f8', 'patches_4th_10k')
# Out:
# Loading ['/Volumes/DATA1/split_cnn/patches_4th_10k/8b33e516-2311-4892-82f9-4e6079c261f8/configuration.txt']
# Loading ['/Volumes/DATA1/split_cnn/patches_4th_10k/8b33e516-2311-4892-82f9-4e6079c261f8/network_19.p']

# %%
SLICE = 70
# zeros are ignored during patch generation!
input_image, input_prob, input_gold, input_rhoana = Util.read_section(SLICE, keep_zeros=True)

# %%
Util.view(input_gold,color=True,large=False)

# %%
Util.view(Util.threshold(input_gold,0),color=False)

# %%
Util.view(input_image, color=False,large=False)

# %%
Util.view_labels(input_gold, [14 ], large=False, crop=True)

# %%
patches_l, patches_n = Patch.grab(input_image, input_prob, input_gold, 14,258, sample_rate=100)

# %%
patches = Patch.patchify(input_image, input_prob, input_gold)

# %%
res = Patch.test(patches, cnn)
# Out:
# N:  940
# Min:  5.70387e-05
# Max:  0.983995
# Mean:  0.0788936
# Std:  0.167789
# Var:  0.0281532

# %%
# most problematic case
Patch.show(patches, cnn, .9)

# %%
#
#
#
# SPLIT TEST
#
#
#


label, border = Patch.split_label(input_image, Util.threshold(input_gold, 14))
while label.max() != 1:
    label, border = Patch.split_label(input_image, Util.threshold(input_gold, 14))

# %%
Util.view_labels(input_gold, [14 ], large=False, crop=False)

# %%
Util.view_labels(label, [1 ], large=False, crop=True)

# %%
Util.view_labels(border, [1 ], large=False, crop=False)

# %%
#split_patches = Patch.analyze_border(input_image, input_prob, label, border)
split_patches_l, split_patches_n = Patch.grab(input_image, input_prob, label, 1, 0)
Patch.show(split_patches_l, cnn, pred_threshold=0)
Patch.show(split_patches_n, cnn, pred_threshold=0)
Patch.test(split_patches_l, cnn)
Patch.test(split_patches_n, cnn)
# Out:
# Min:  0.192158
# Max:  0.99969
# Mean:  0.847225
# Std:  0.295483
# Var:  0.0873104
# Min:
#  0.192158
# Max:  0.99969
# Mean:  0.847225
# Std:  0.295483
# Var:  0.0873104
# [0.99886215, 0.19215792, 0.99967664, 0.8937366, 0.99968976, 0.99923015]

# %%
#
#
#
# GENERATOR TEST
#
#
#



from generator import *
c_patches = []
for p in Generator.generate_correct(input_image, input_prob, input_gold):
    c_patches.append(p)

# %%
s_patches = []
for p in Generator.generate_split_error(input_image, input_prob, input_gold):
    s_patches.append(p)
# Out:
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..
# Caught empty..

# %%
len(s_patches)
# Out:
# 2724

# %%
s_patches_result = Patch.test(s_patches, cnn)
