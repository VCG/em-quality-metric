# %%
# %load_ext autoreload
# %autoreload 2

from cnn import CNN
from util import Util

from patch import Patch
import mahotas as mh
import numpy as np

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is disabled)

# %%
SLICE = 70
# zeros are ignored during patch generation!
input_image, input_prob, input_gold, input_rhoana = Util.read_section(SLICE, keep_zeros=True)

# %%
Util.view(input_gold, large=True)
print input_gold[400,270]
print input_gold[400,2]
# Out:
# 235
# 14

# %%
patches_l, patches_n = Patch.grab(input_image, input_prob, input_gold, 14,235, sample_rate=10, patch_size=(75,75))

# %%
Patch.show(patches_n, None, .9)

# %%
75/2
# Out:
# 37

# %%
patches = Patch.patchify(input_image, input_prob, input_gold, sample_rate=10)

# %%
len(patches)
# Out:
# 940

# %%
Patch.show(patches[0:3])
