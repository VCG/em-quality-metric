# %%
from __future__ import division, print_function

# %load_ext autoreload
# %autoreload 2

IMAGE_HEIGHT = 75
IMAGE_WIDTH = 75

import scipy
import theano
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
# %matplotlib inline

from sklearn.datasets import fetch_mldata
from sklearn.cross_validation import train_test_split

from nolearn.lasagne import NeuralNet
from lasagne import layers
from lasagne import nonlinearities
from lasagne.updates import nesterov_momentum


from util import Util
# Out:
# tifffile.py:1995: UserWarning: failed to import _tifffile.decodepackbits
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.decodelzw
#   warnings.warn("failed to import %s" % module_function)
# tifffile.py:1995: UserWarning: failed to import _tifffile.unpackints
#   warnings.warn("failed to import %s" % module_function)

# %%
X_train, y_train, X_val, y_val, X_test, y_test = Util.load_dataset('patches_8th_small')

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# X_train = X_train.reshape(-1, 1, IMAGE_HEIGHT, IMAGE_WIDTH)
# X_test = X_test.reshape(-1, 1, IMAGE_HEIGHT, IMAGE_WIDTH)

print(X_train['image'].shape, X_val['image'].shape)
# Out:
# (11496, 1, 75, 75) (14928, 1, 75, 75)

# %%
clf = NeuralNet(
    layers=[
        ('input', layers.InputLayer),

        ('conv1', layers.Conv2DLayer),
        ('pool1', layers.MaxPool2DLayer),
        ('dropout1', layers.DropoutLayer),

        ('conv2', layers.Conv2DLayer),
        ('pool2', layers.MaxPool2DLayer),
        ('dropout2', layers.DropoutLayer),

        ('hidden3', layers.DenseLayer),
        ('dropout3', layers.DropoutLayer),
        ('output', layers.DenseLayer),
    ],

    # input
    input_shape=(None, 1, 75, 75),

    # conv2d + pool + dropout
    conv1_filter_size=(5,5), conv1_num_filters=32,
    pool1_pool_size=(2,2),
    dropout1_p=0.1,

    # conv2d + pool + dropout
    conv2_filter_size=(5,5), conv2_num_filters=32,
    pool2_pool_size=(2,2),
    dropout2_p=0.2,

    # dense layer 1
    hidden3_num_units=256,
    hidden3_nonlinearity=nonlinearities.rectify,
    dropout3_p=0.5,

    # dense layer 2
    output_num_units=2,
    output_nonlinearity=nonlinearities.softmax,



    update=nesterov_momentum,
    update_learning_rate=0.01,
    update_momentum=0.9,

    max_epochs=50,
    verbose=True
)

clf.fit(X_train, y_train)
# Out:
# # Neural Network with 160362 learnable parameters
#
# ## Layer information
#
#   #  name      size
# ---  --------  --------
#   0  input     1x28x28
#   1  conv1     32x24x24
#   2  pool1     32x12x12
#   3  dropout1  32x12x12
#   4  conv2     32x8x8
#   5  pool2     32x4x4
#   6  dropout2  32x4x4
#   7  hidden3   256
#   8  dropout3  256
#   9  output    10
#   epoch    train loss    valid loss    train/val    valid acc  dur
# -------  ------------  ------------  -----------  -----------  ------
#       1       0.63594       0.13309      4.77834      0.95924  10.48s
#       2       0.17609       0.09077      1.93987      0.97091  9.69s
#       3       0.13065       0.07196      1.81552      0.97722  9.72s
#       4       0.10627       0.05885      1.80577      0.98070  9.72s
#       5       0.09090       0.05327      1.70636      0.98343  9.69s
#       6       0.08107       0.04885      1.65958      0.98485  9.68s
#       7       0.07542       0.04418      1.70704      0.98645  9.70s
# /Users/d/Library/Python/2.7/lib/python/site-packages/theano/tensor/nnet/__init__.py:111: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   warnings.warn("The `image_shape` keyword argument to "
# NeuralNet(X_tensor_type=None,
#      batch_iterator_test=<nolearn.lasagne.base.BatchIterator object at 0x11aa21990>,
#      batch_iterator_train=<nolearn.lasagne.base.BatchIterator object at 0x11aa21850>,
#      check_input=True, conv1_filter_size=(5, 5), conv1_num_filters=32,
#      conv2_filter_size=(5, 5), conv2_num_filters=32, custom_scores=None,
#      dropout1_p=0.1, dropout2_p=0.2, dropout3_p=0.5, hidden3_num_units=256,
#      input_shape=(None, 1, 28, 28),
#      layers=[('input', <class 'lasagne.layers.input.InputLayer'>), ('conv1', <class 'lasagne.layers.conv.Conv2DLayer'>), ('pool1', <class 'lasagne.layers.pool.MaxPool2DLayer'>), ('dropout1', <class 'lasagne.layers.noise.DropoutLayer'>), ('conv2', <class 'lasagne.layers.conv.Conv2DLayer'>), ('pool2', <cla...<class 'lasagne.layers.noise.DropoutLayer'>), ('output', <class 'lasagne.layers.dense.DenseLayer'>)],
#      loss=None, max_epochs=50, more_params={},
#      objective=<function objective at 0x11aa29758>,
#      objective_loss_function=<function categorical_crossentropy at 0x11aa0ff50>,
#      on_batch_finished=[],
#      on_epoch_finished=[<nolearn.lasagne.handlers.PrintLog instance at 0x11aa3e9e0>],
#      on_training_finished=[],
#      on_training_started=[<nolearn.lasagne.handlers.PrintLayerInfo instance at 0x11aa3ea28>],
#      output_nonlinearity=<function softmax at 0x11a9e9140>,
#      output_num_units=10, pool1_pool_size=(2, 2), pool2_pool_size=(2, 2),
#      regression=False,
#      train_split=<nolearn.lasagne.base.TrainSplit object at 0x11aa21a10>,
#      update=<function nesterov_momentum at 0x11aa1b9b0>,
#      update_learning_rate=0.01, update_momentum=0.9,
#      use_label_encoder=False, verbose=True,
#      y_tensor_type=TensorType(int32, vector))

# %%
clf.score(X_test, y_test)
# Out:
# 0.9873714285714286

# %%
clf_layers = clf.get_all_layers()

# %%
layer = clf_layers[1]
W = layer.W.get_value()
b = layer.b.get_value()
f = [w + bb for w, bb in zip(W, b)]

gs = gridspec.GridSpec(6, 6)
for i in range(layer.num_filters):
    g = gs[i]
    ax = plt.subplot(g)
    ax.grid()
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(f[i][0], cmap='gray')

# %%
output = layer.get_output_for(X_test[:1]).eval()[0]
gs = gridspec.GridSpec(6, 6)
for i in range(layer.num_filters):
    g = gs[i]
    ax = plt.subplot(g)
    ax.grid()
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(output[i], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d04d6ef588df> in <module>()
# ----> 1 output = layer.get_output_for(X_test[:1]).eval()[0]
#       2 gs = gridspec.GridSpec(6, 6)
#       3 for i in range(layer.num_filters):
#       4     g = gs[i]
#       5     ax = plt.subplot(g)
#
# /Users/d/Library/Python/2.7/lib/python/site-packages/lasagne/layers/conv.pyc in get_output_for(self, input, input_shape, **kwargs)
#     487                                       image_shape=input_shape,
#     488                                       filter_shape=self.get_W_shape(),
# --> 489                                       border_mode=border_mode)
#     490
#     491         if self.b is None:
#
# /Users/d/Library/Python/2.7/lib/python/site-packages/theano/tensor/nnet/__init__.pyc in conv2d(input, filters, input_shape, filter_shape, border_mode, subsample, filter_flip, image_shape, **kwargs)
#     119
#     120     return abstract_conv2d(input, filters, input_shape, filter_shape,
# --> 121                            border_mode, subsample, filter_flip)
#     122
#     123
#
# /Users/d/Library/Python/2.7/lib/python/site-packages/theano/tensor/nnet/abstract_conv.pyc in conv2d(input, filters, input_shape, filter_shape, border_mode, subsample, filter_flip)
#     175                              subsample=subsample,
#     176                              filter_flip=filter_flip)
# --> 177     return conv_op(input, filters)
#     178
#     179
#
# /Users/d/Library/Python/2.7/lib/python/site-packages/theano/gof/op.pyc in __call__(self, *inputs, **kwargs)
#     598         """
#     599         return_list = kwargs.pop('return_list', False)
# --> 600         node = self.make_node(*inputs, **kwargs)
#     601
#     602         if config.compute_test_value != 'off':
#
# /Users/d/Library/Python/2.7/lib/python/site-packages/theano/tensor/nnet/abstract_conv.pyc in make_node(self, img, kern)
#     287
#     288     def make_node(self, img, kern):
# --> 289         if img.type.ndim != 4:
#     290             raise TypeError('img must be 4D tensor')
#     291         if kern.type.ndim != 4:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
layer = clf_layers[4]
W = layer.W.get_value()
b = layer.b.get_value()
f = [w + bb for w, bb in zip(W, b)]

gs = gridspec.GridSpec(6, 6)
for i in range(layer.num_filters):
    g = gs[i]
    ax = plt.subplot(g)
    ax.grid()
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(f[i][0], cmap='gray')

# %%
clf_layers
# Out:
# [<lasagne.layers.input.InputLayer at 0x111912ad0>,
#  <lasagne.layers.conv.Conv2DLayer at 0x11aa500d0>,
#  <lasagne.layers.pool.MaxPool2DLayer at 0x11aa50090>,
#  <lasagne.layers.noise.DropoutLayer at 0x11ab03110>,
#  <lasagne.layers.conv.Conv2DLayer at 0x11ab03150>,
#  <lasagne.layers.pool.MaxPool2DLayer at 0x11ab03410>,
#  <lasagne.layers.noise.DropoutLayer at 0x11ab03450>,
#  <lasagne.layers.dense.DenseLayer at 0x11ab03490>,
#  <lasagne.layers.noise.DropoutLayer at 0x11ab03b10>,
#  <lasagne.layers.dense.DenseLayer at 0x11ab03ad0>]
